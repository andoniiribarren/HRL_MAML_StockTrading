# %% [markdown]
# # Data Prep

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from src.preprocess.preprocessor import get_df
from src.config_training import TrainSettings

settings = TrainSettings()

TRAIN_START_DATE = settings.TRAIN_START_DATE
TRAIN_END_DATE = settings.TRAIN_END_DATE
VAL_START_DATE = settings.VAL_START_DATE
VAL_END_DATE = settings.VAL_END_DATE

TEST23_START_DATE = settings.TEST23_START_DATE
TEST23_END_DATE = settings.TEST23_END_DATE
TEST24_START_DATE = settings.TEST24_START_DATE
TEST24_END_DATE = settings.TEST24_END_DATE

INDICATORS = settings.INDICATORS
tickerlist = "DOW_30_red"

df_train = get_df(start= TRAIN_START_DATE, end=TRAIN_END_DATE, json_path= "../src/preprocess/tickers/ticker_lists.json", tickerlist=tickerlist)
df_val = get_df(start= VAL_START_DATE, end=VAL_END_DATE, json_path= "../src/preprocess/tickers/ticker_lists.json", tickerlist=tickerlist)
df_test23 = get_df(start= TEST23_START_DATE, end=TEST23_END_DATE, json_path= "../src/preprocess/tickers/ticker_lists.json", tickerlist=tickerlist)
df_test24 = get_df(start= TEST24_START_DATE, end=TEST24_END_DATE, json_path= "../src/preprocess/tickers/ticker_lists.json", tickerlist=tickerlist)
stock_dimension = len(df_train.tic.unique())
# Out:
# Downloading 10 assets:
# From: 2017-12-02 00:00:00
# To: 2022-01-01
# Shape of DataFrame:  (10270, 8)
# Successfully added technical indicators
# Downloading 10 assets:
# From: 2021-12-02 00:00:00
# To: 2023-01-01
# Shape of DataFrame:  (2720, 8)
# Successfully added technical indicators
# Downloading 10 assets:
# From: 2022-12-02 00:00:00
# To: 2024-01-01
# Shape of DataFrame:  (2700, 8)
# Successfully added technical indicators
# Downloading 10 assets:
# From: 2023-12-02 00:00:00
# To: 2025-01-01
# Shape of DataFrame:  (2710, 8)
# Successfully added technical indicators

# %% [markdown]
# # HRL

# %%
#OPTUNA
from hyperparameter_searching.HRL_optuna_utils import hyperparams_opt_HRL
N_TRIALS = 40
hrl_opt = hyperparams_opt_HRL(
    df_train=df_train, df_test=df_val, indicators=INDICATORS, n_trials=N_TRIALS
)
#hrl_opt.run_opt()
# Out:
# day: 1007, episode: 18
# begin_total_asset: 1000000.00
# end_total_asset: 1641497.41
# total_reward: 641497.41
# total_cost: 25202.32
# total_trades: 7757
# Sharpe: 0.635
# =================================
# day: 1007, episode: 19
# begin_total_asset: 1000000.00
# end_total_asset: 1676661.18
# total_reward: 676661.18
# total_cost: 25697.96
# total_trades: 9728
# Sharpe: 0.629
# =================================
# day: 1007, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1501787.13
# total_reward: 501787.13
# total_cost: 23959.47
# total_trades: 9453
# Sharpe: 0.507
# =================================
# day: 1007, episode: 21
# begin_total_asset: 1000000.00
# end_total_asset: 1476079.62
# total_reward: 476079.62
# total_cost: 24175.44
# total_trades: 9189
# Sharpe: 0.482
# =================================
# day: 1007, episode: 22
# begin_total_asset: 1000000.00
# end_total_asset: 1516459.97
# total_reward: 516459.97
# total_cost: 25120.67
# total_trades: 9138
# Sharpe: 0.510
# =================================
# day: 1007, episode: 23
# begin_total_asset: 1000000.00
# end_total_asset: 1643801.73
# total_reward: 643801.73
# total_cost: 28730.97
# total_trades: 8787
# Sharpe: 0.573
# =================================
# day: 1007, episode: 24
# begin_total_asset: 1000000.00
# end_total_asset: 1778085.06
# total_reward: 778085.06
# total_cost: 30626.86
# total_trades: 8044
# Sharpe: 0.747
# =================================
# day: 1007, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1874761.86
# total_reward: 874761.86
# total_cost: 35540.77
# total_trades: 8315
# Sharpe: 0.858
# =================================
# day: 1007, episode: 26
# begin_total_asset: 1000000.00
# end_total_asset: 1839216.26
# total_reward: 839216.26
# total_cost: 37300.16
# total_trades: 7957
# Sharpe: 0.811
# =================================
# day: 1007, episode: 27
# begin_total_asset: 1000000.00
# end_total_asset: 1746563.64
# total_reward: 746563.64
# total_cost: 32247.47
# total_trades: 7566
# Sharpe: 0.721
# =================================
# day: 1007, episode: 28
# begin_total_asset: 1000000.00
# end_total_asset: 1725361.01
# total_reward: 725361.01
# total_cost: 29411.49
# total_trades: 7519
# Sharpe: 0.709
# =================================
# day: 1007, episode: 29
# begin_total_asset: 1000000.00
# end_total_asset: 1799173.44
# total_reward: 799173.44
# total_cost: 26769.63
# total_trades: 7211
# Sharpe: 0.740
# =================================
# day: 1007, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1722136.15
# total_reward: 722136.15
# total_cost: 25840.40
# total_trades: 7129
# Sharpe: 0.693
# =================================
# Starting Phase 3: Alternate training
# day: 1007, episode: 31
# begin_total_asset: 1000000.00
# end_total_asset: 1520909.01
# total_reward: 520909.01
# total_cost: 104546.47
# total_trades: 11387
# Sharpe: 0.562
# =================================
# day: 1007, episode: 32
# begin_total_asset: 1000000.00
# end_total_asset: 1630959.05
# total_reward: 630959.05
# total_cost: 97336.60
# total_trades: 11025
# Sharpe: 0.630
# =================================
# day: 1007, episode: 33
# begin_total_asset: 1000000.00
# end_total_asset: 1578769.15
# total_reward: 578769.15
# total_cost: 101199.21
# total_trades: 11080
# Sharpe: 0.634
# =================================
# day: 1007, episode: 34
# begin_total_asset: 1000000.00
# end_total_asset: 1427314.95
# total_reward: 427314.95
# total_cost: 87005.86
# total_trades: 10716
# Sharpe: 0.483
# =================================
# day: 1007, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1682709.07
# total_reward: 682709.07
# total_cost: 25793.64
# total_trades: 7085
# Sharpe: 0.674
# =================================
# day: 1007, episode: 36
# begin_total_asset: 1000000.00
# end_total_asset: 1619860.14
# total_reward: 619860.14
# total_cost: 23339.08
# total_trades: 7135
# Sharpe: 0.628
# =================================
# day: 1007, episode: 37
# begin_total_asset: 1000000.00
# end_total_asset: 1517118.66
# total_reward: 517118.66
# total_cost: 23863.88
# total_trades: 7030
# Sharpe: 0.565
# =================================
# day: 1007, episode: 38
# begin_total_asset: 1000000.00
# end_total_asset: 1559880.67
# total_reward: 559880.67
# total_cost: 21717.13
# total_trades: 6709
# Sharpe: 0.588
# =================================
# [Cycle 1/5] done
# day: 1007, episode: 39
# begin_total_asset: 1000000.00
# end_total_asset: 1401990.68
# total_reward: 401990.68
# total_cost: 70186.20
# total_trades: 9281
# Sharpe: 0.464
# =================================
# day: 1007, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1600615.17
# total_reward: 600615.17
# total_cost: 84082.71
# total_trades: 9672
# Sharpe: 0.637
# =================================
# day: 1007, episode: 41
# begin_total_asset: 1000000.00
# end_total_asset: 1435975.83
# total_reward: 435975.83
# total_cost: 80577.12
# total_trades: 9504
# Sharpe: 0.494
# =================================
# day: 1007, episode: 42
# begin_total_asset: 1000000.00
# end_total_asset: 1446196.23
# total_reward: 446196.23
# total_cost: 79528.84
# total_trades: 9643
# Sharpe: 0.514
# =================================
# day: 1007, episode: 43
# begin_total_asset: 1000000.00
# end_total_asset: 1500371.79
# total_reward: 500371.79
# total_cost: 24851.00
# total_trades: 7028
# Sharpe: 0.577
# =================================
# day: 1007, episode: 44
# begin_total_asset: 1000000.00
# end_total_asset: 1636774.68
# total_reward: 636774.68
# total_cost: 25768.67
# total_trades: 7137
# Sharpe: 0.659
# =================================
# day: 1007, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1674444.77
# total_reward: 674444.77
# total_cost: 26539.41
# total_trades: 7151
# Sharpe: 0.685
# =================================
# day: 1007, episode: 46
# begin_total_asset: 1000000.00
# end_total_asset: 1662705.70
# total_reward: 662705.70
# total_cost: 24614.27
# total_trades: 7038
# Sharpe: 0.669
# =================================
# [Cycle 2/5] done
# day: 1007, episode: 47
# begin_total_asset: 1000000.00
# end_total_asset: 1667415.57
# total_reward: 667415.57
# total_cost: 95336.93
# total_trades: 10442
# Sharpe: 0.741
# =================================
# day: 1007, episode: 48
# begin_total_asset: 1000000.00
# end_total_asset: 1635417.83
# total_reward: 635417.83
# total_cost: 92794.11
# total_trades: 10322
# Sharpe: 0.687
# =================================
# day: 1007, episode: 49
# begin_total_asset: 1000000.00
# end_total_asset: 1375145.18
# total_reward: 375145.18
# total_cost: 98363.15
# total_trades: 10763
# Sharpe: 0.478
# =================================
# day: 1007, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1602429.08
# total_reward: 602429.08
# total_cost: 90531.70
# total_trades: 10125
# Sharpe: 0.644
# =================================
# day: 1007, episode: 51
# begin_total_asset: 1000000.00
# end_total_asset: 1741968.23
# total_reward: 741968.23
# total_cost: 26158.81
# total_trades: 7446
# Sharpe: 0.714
# =================================
# day: 1007, episode: 52
# begin_total_asset: 1000000.00
# end_total_asset: 1696244.51
# total_reward: 696244.51
# total_cost: 25922.71
# total_trades: 7136
# Sharpe: 0.676
# =================================
# day: 1007, episode: 53
# begin_total_asset: 1000000.00
# end_total_asset: 1718097.67
# total_reward: 718097.67
# total_cost: 23908.23
# total_trades: 6932
# Sharpe: 0.685
# =================================
# day: 1007, episode: 54
# begin_total_asset: 1000000.00
# end_total_asset: 1660867.14
# total_reward: 660867.14
# total_cost: 24661.75
# total_trades: 7252
# Sharpe: 0.656
# =================================
# [Cycle 3/5] done
# day: 1007, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1836717.76
# total_reward: 836717.76
# total_cost: 88387.78
# total_trades: 10683
# Sharpe: 0.743
# =================================
# day: 1007, episode: 56
# begin_total_asset: 1000000.00
# end_total_asset: 1868859.71
# total_reward: 868859.71
# total_cost: 80302.67
# total_trades: 10459
# Sharpe: 0.750
# =================================
# day: 1007, episode: 57
# begin_total_asset: 1000000.00
# end_total_asset: 1942411.70
# total_reward: 942411.70
# total_cost: 79938.38
# total_trades: 10529
# Sharpe: 0.803
# =================================
# day: 1007, episode: 58
# begin_total_asset: 1000000.00
# end_total_asset: 1919855.53
# total_reward: 919855.53
# total_cost: 70485.02
# total_trades: 10184
# Sharpe: 0.744
# =================================
# day: 1007, episode: 59
# begin_total_asset: 1000000.00
# end_total_asset: 1745519.31
# total_reward: 745519.31
# total_cost: 21755.49
# total_trades: 8101
# Sharpe: 0.666
# =================================
# day: 1007, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1795894.63
# total_reward: 795894.63
# total_cost: 23207.33
# total_trades: 8261
# Sharpe: 0.672
# =================================
# day: 1007, episode: 61
# begin_total_asset: 1000000.00
# end_total_asset: 1734214.79
# total_reward: 734214.79
# total_cost: 23290.20
# total_trades: 8030
# Sharpe: 0.639
# =================================
# day: 1007, episode: 62
# begin_total_asset: 1000000.00
# end_total_asset: 1654873.34
# total_reward: 654873.34
# total_cost: 22801.42
# total_trades: 7946
# Sharpe: 0.606
# =================================
# [Cycle 4/5] done
# day: 1007, episode: 63
# begin_total_asset: 1000000.00
# end_total_asset: 1583010.68
# total_reward: 583010.68
# total_cost: 110263.54
# total_trades: 12551
# Sharpe: 0.640
# =================================
# day: 1007, episode: 64
# begin_total_asset: 1000000.00
# end_total_asset: 1494825.44
# total_reward: 494825.44
# total_cost: 113337.85
# total_trades: 12737
# Sharpe: 0.568
# =================================
# day: 1007, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1510366.05
# total_reward: 510366.05
# total_cost: 114678.08
# total_trades: 12764
# Sharpe: 0.565
# =================================
# day: 1007, episode: 66
# begin_total_asset: 1000000.00
# end_total_asset: 1769894.91
# total_reward: 769894.91
# total_cost: 121278.69
# total_trades: 12705
# Sharpe: 0.739
# =================================
# day: 1007, episode: 67
# begin_total_asset: 1000000.00
# end_total_asset: 1815786.23
# total_reward: 815786.23
# total_cost: 22188.46
# total_trades: 7795
# Sharpe: 0.647
# =================================
# day: 1007, episode: 68
# begin_total_asset: 1000000.00
# end_total_asset: 1734795.15
# total_reward: 734795.15
# total_cost: 21877.17
# total_trades: 7705
# Sharpe: 0.601
# =================================
# day: 1007, episode: 69
# begin_total_asset: 1000000.00
# end_total_asset: 1811097.98
# total_reward: 811097.98
# total_cost: 23716.53
# total_trades: 7729
# Sharpe: 0.652
# =================================
# day: 1007, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1765420.39
# total_reward: 765420.39
# total_cost: 23347.31
# total_trades: 7890
# Sharpe: 0.634
# =================================
# [Cycle 5/5] done
# Retrieving memory from env...
# day: 250, episode: 1
# begin_total_asset: 1000000.00
# end_total_asset: 683248.36
# total_reward: -316751.64
# total_cost: 8265.11
# total_trades: 2224
# Sharpe: -1.383
# =================================
# Retrieving memory from env...
# Hit end!
# [I 2025-12-16 09:57:52,018] Trial 1 finished with value: 683248.3599976574 and parameters: {'lr_actor_M': 0.00045084023484830713, 'lr_critic_M': 0.0009494204170968856, 'gamma_M': 0.9935060478574778, 'update_timestep': 4096, 'gamma_W': 0.9972340698003559, 'lr_W': 0.00044649041897470233, 'buffer_size': 40000, 'batch_size': 1024}. Best is trial 0 with value: 990977.7017406926.
# Starting Phase 1: Only train Manager
# day: 1007, episode: 1
# begin_total_asset: 1000000.00
# end_total_asset: 1187549.08
# total_reward: 187549.08
# total_cost: 86664.77
# total_trades: 17191
# Sharpe: 0.296
# =================================
# day: 1007, episode: 2
# begin_total_asset: 1000000.00
# end_total_asset: 990352.60
# total_reward: -9647.40
# total_cost: 76200.00
# total_trades: 16821
# Sharpe: 0.148
# =================================
# day: 1007, episode: 3
# begin_total_asset: 1000000.00
# end_total_asset: 1345717.34
# total_reward: 345717.34
# total_cost: 88765.91
# total_trades: 17563
# Sharpe: 0.452
# =================================
# day: 1007, episode: 4
# begin_total_asset: 1000000.00
# end_total_asset: 1084918.49
# total_reward: 84918.49
# total_cost: 83781.98
# total_trades: 17214
# Sharpe: 0.205
# =================================
# day: 1007, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1461784.47
# total_reward: 461784.47
# total_cost: 95005.82
# total_trades: 17839
# Sharpe: 0.548
# =================================
# day: 1007, episode: 6
# begin_total_asset: 1000000.00
# end_total_asset: 1003060.15
# total_reward: 3060.15
# total_cost: 84442.45
# total_trades: 17101
# Sharpe: 0.152
# =================================
# day: 1007, episode: 7
# begin_total_asset: 1000000.00
# end_total_asset: 1305635.23
# total_reward: 305635.23
# total_cost: 94157.42
# total_trades: 17793
# Sharpe: 0.401
# =================================
# day: 1007, episode: 8
# begin_total_asset: 1000000.00
# end_total_asset: 1409198.10
# total_reward: 409198.10
# total_cost: 99582.54
# total_trades: 18135
# Sharpe: 0.511
# =================================
# day: 1007, episode: 9
# begin_total_asset: 1000000.00
# end_total_asset: 1257932.86
# total_reward: 257932.86
# total_cost: 87481.10
# total_trades: 17523
# Sharpe: 0.357
# =================================
# day: 1007, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1457753.14
# total_reward: 457753.14
# total_cost: 100362.03
# total_trades: 18166
# Sharpe: 0.533
# =================================
# day: 1007, episode: 11
# begin_total_asset: 1000000.00
# end_total_asset: 1195564.76
# total_reward: 195564.76
# total_cost: 84055.53
# total_trades: 17235
# Sharpe: 0.302
# =================================
# day: 1007, episode: 12
# begin_total_asset: 1000000.00
# end_total_asset: 1204653.68
# total_reward: 204653.68
# total_cost: 93161.88
# total_trades: 17742
# Sharpe: 0.312
# =================================
# day: 1007, episode: 13
# begin_total_asset: 1000000.00
# end_total_asset: 1049582.07
# total_reward: 49582.07
# total_cost: 85806.46
# total_trades: 17369
# Sharpe: 0.183
# =================================
# day: 1007, episode: 14
# begin_total_asset: 1000000.00
# end_total_asset: 1225155.88
# total_reward: 225155.88
# total_cost: 83612.00
# total_trades: 17181
# Sharpe: 0.324
# =================================
# day: 1007, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1116539.56
# total_reward: 116539.56
# total_cost: 82889.31
# total_trades: 17071
# Sharpe: 0.236
# =================================
# day: 1007, episode: 16
# begin_total_asset: 1000000.00
# end_total_asset: 1252468.85
# total_reward: 252468.85
# total_cost: 92069.16
# total_trades: 17673
# Sharpe: 0.354
# =================================
# day: 1007, episode: 17
# begin_total_asset: 1000000.00
# end_total_asset: 1573237.58
# total_reward: 573237.58
# total_cost: 95582.75
# total_trades: 17829
# Sharpe: 0.623
# =================================
# Starting Phase 2: Only train Worker
# day: 1007, episode: 18
# begin_total_asset: 1000000.00
# end_total_asset: 1445275.80
# total_reward: 445275.80
# total_cost: 19810.94
# total_trades: 7559
# Sharpe: 0.514
# =================================
# day: 1007, episode: 19
# begin_total_asset: 1000000.00
# end_total_asset: 2008595.36
# total_reward: 1008595.36
# total_cost: 15011.00
# total_trades: 8307
# Sharpe: 0.839
# =================================
# day: 1007, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1481395.30
# total_reward: 481395.30
# total_cost: 15299.88
# total_trades: 8824
# Sharpe: 0.560
# =================================
# day: 1007, episode: 21
# begin_total_asset: 1000000.00
# end_total_asset: 1564163.30
# total_reward: 564163.30
# total_cost: 13794.79
# total_trades: 8576
# Sharpe: 0.615
# =================================
# day: 1007, episode: 22
# begin_total_asset: 1000000.00
# end_total_asset: 1625220.04
# total_reward: 625220.04
# total_cost: 10947.77
# total_trades: 8249
# Sharpe: 0.647
# =================================
# day: 1007, episode: 23
# begin_total_asset: 1000000.00
# end_total_asset: 1637397.41
# total_reward: 637397.41
# total_cost: 10749.42
# total_trades: 8136
# Sharpe: 0.654
# =================================
# day: 1007, episode: 24
# begin_total_asset: 1000000.00
# end_total_asset: 1209693.59
# total_reward: 209693.59
# total_cost: 13523.55
# total_trades: 8132
# Sharpe: 0.319
# =================================
# day: 1007, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1276183.19
# total_reward: 276183.19
# total_cost: 16745.95
# total_trades: 8490
# Sharpe: 0.385
# =================================
# day: 1007, episode: 26
# begin_total_asset: 1000000.00
# end_total_asset: 1382798.87
# total_reward: 382798.87
# total_cost: 16306.40
# total_trades: 8701
# Sharpe: 0.474
# =================================
# day: 1007, episode: 27
# begin_total_asset: 1000000.00
# end_total_asset: 1291472.75
# total_reward: 291472.75
# total_cost: 16636.13
# total_trades: 8579
# Sharpe: 0.390
# =================================
# day: 1007, episode: 28
# begin_total_asset: 1000000.00
# end_total_asset: 1207842.26
# total_reward: 207842.26
# total_cost: 16811.73
# total_trades: 8633
# Sharpe: 0.318
# =================================
# day: 1007, episode: 29
# begin_total_asset: 1000000.00
# end_total_asset: 1304587.86
# total_reward: 304587.86
# total_cost: 18441.74
# total_trades: 8578
# Sharpe: 0.401
# =================================
# day: 1007, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1170769.56
# total_reward: 170769.56
# total_cost: 16173.32
# total_trades: 7936
# Sharpe: 0.284
# =================================
# Starting Phase 3: Alternate training
# day: 1007, episode: 31
# begin_total_asset: 1000000.00
# end_total_asset: 1228483.59
# total_reward: 228483.59
# total_cost: 156519.05
# total_trades: 15625
# Sharpe: 0.335
# =================================
# day: 1007, episode: 32
# begin_total_asset: 1000000.00
# end_total_asset: 1169883.84
# total_reward: 169883.84
# total_cost: 154481.73
# total_trades: 15701
# Sharpe: 0.285
# =================================
# day: 1007, episode: 33
# begin_total_asset: 1000000.00
# end_total_asset: 1145386.46
# total_reward: 145386.46
# total_cost: 159851.89
# total_trades: 15906
# Sharpe: 0.263
# =================================
# day: 1007, episode: 34
# begin_total_asset: 1000000.00
# end_total_asset: 780687.78
# total_reward: -219312.22
# total_cost: 135089.70
# total_trades: 15132
# Sharpe: -0.080
# =================================
# day: 1007, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 786967.63
# total_reward: -213032.37
# total_cost: 12773.21
# total_trades: 7005
# Sharpe: 0.013
# =================================
# day: 1007, episode: 36
# begin_total_asset: 1000000.00
# end_total_asset: 792326.63
# total_reward: -207673.37
# total_cost: 12466.00
# total_trades: 6669
# Sharpe: 0.017
# =================================
# day: 1007, episode: 37
# begin_total_asset: 1000000.00
# end_total_asset: 852790.41
# total_reward: -147209.59
# total_cost: 14674.78
# total_trades: 6906
# Sharpe: 0.045
# =================================
# day: 1007, episode: 38
# begin_total_asset: 1000000.00
# end_total_asset: 939071.87
# total_reward: -60928.13
# total_cost: 15899.95
# total_trades: 6796
# Sharpe: 0.098
# =================================
# [Cycle 1/5] done
# day: 1007, episode: 39
# begin_total_asset: 1000000.00
# end_total_asset: 1263697.91
# total_reward: 263697.91
# total_cost: 141381.99
# total_trades: 13355
# Sharpe: 0.379
# =================================
# day: 1007, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1249839.60
# total_reward: 249839.60
# total_cost: 120640.44
# total_trades: 12587
# Sharpe: 0.368
# =================================
# day: 1007, episode: 41
# begin_total_asset: 1000000.00
# end_total_asset: 1506649.62
# total_reward: 506649.62
# total_cost: 138299.44
# total_trades: 13064
# Sharpe: 0.574
# =================================
# day: 1007, episode: 42
# begin_total_asset: 1000000.00
# end_total_asset: 1576074.05
# total_reward: 576074.05
# total_cost: 147610.29
# total_trades: 13383
# Sharpe: 0.653
# =================================
# day: 1007, episode: 43
# begin_total_asset: 1000000.00
# end_total_asset: 958330.03
# total_reward: -41669.97
# total_cost: 15481.41
# total_trades: 6918
# Sharpe: 0.108
# =================================
# day: 1007, episode: 44
# begin_total_asset: 1000000.00
# end_total_asset: 990898.67
# total_reward: -9101.33
# total_cost: 16563.09
# total_trades: 6908
# Sharpe: 0.128
# =================================
# day: 1007, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1001875.53
# total_reward: 1875.53
# total_cost: 17083.97
# total_trades: 6998
# Sharpe: 0.137
# =================================
# [W 2025-12-16 10:11:22,194] Trial 2 failed with parameters: {'lr_actor_M': 6.357889562858175e-05, 'lr_critic_M': 0.00044896596708690975, 'gamma_M': 0.9894136526241157, 'update_timestep': 4096, 'gamma_W': 0.9807386751515403, 'lr_W': 0.00022836214249326813, 'buffer_size': 40000, 'batch_size': 128} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\src\hyperparameter_searching\HRL_optuna_utils.py", line 114, in objective
#     trained_model = model.train_HRL_model()
#                     ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\src\agent\HRL_model.py", line 278, in train_HRL_model
#     self.alternate_training()
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\src\agent\HRL_model.py", line 262, in alternate_training
#     self.trainHRL(
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\src\agent\HRL_model.py", line 159, in trainHRL
#     self.worker.train(
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\stable_baselines3\td3\td3.py", line 179, in train
#     current_q_values = self.critic(replay_data.observations, replay_data.actions)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\stable_baselines3\common\policies.py", line 977, in forward
#     return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\stable_baselines3\common\policies.py", line 977, in <genexpr>
#     return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#                  ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\container.py", line 217, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\linear.py", line 116, in forward
#     return F.linear(input, self.weight, self.bias)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2025-12-16 10:11:22,499] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       3 N_TRIALS = 40
#       4 hrl_opt = hyperparams_opt_HRL(
#       5     df_train=df_train, df_test=df_val, indicators=INDICATORS, n_trials=N_TRIALS
#       6 )
# ----> 7 hrl_opt.run_opt()
#
# File ~\Desktop\TFM\HRL_MAML_StockTrading\src\hyperparameter_searching\HRL_optuna_utils.py:122, in hyperparams_opt_HRL.run_opt(self)
#     120 def run_opt(self):
#     121     study = optuna.create_study(direction="maximize")
# --> 122     study.optimize(self.objective, n_trials=self.n_trials)
#     124     print(f"Best hiperparams: {study.best_params}")
#     126     t = study.best_trial
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\optuna\study\_optimize.py:67, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      65 try:
#      66     if n_jobs == 1:
# ---> 67         _optimize_sequential(
#      68             study,
#      69             func,
#      70             n_trials,
#      71             timeout,
#      72             catch,
#      73             callbacks,
#      74             gc_after_trial,
#      75             reseed_sampler_rng=False,
#      76             time_start=None,
#      77             progress_bar=progress_bar,
#      78         )
#      79     else:
#      80         if n_jobs == -1:
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\optuna\study\_optimize.py:164, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161         break
#     163 try:
# --> 164     frozen_trial_id = _run_trial(study, func, catch)
#     165 finally:
#     166     # The following line mitigates memory problems that can be occurred in some
#     167     # environments (e.g., services that use computing containers such as GitHub Actions).
#     168     # Please refer to the following PR for further details:
#     169     # https://github.com/optuna/optuna/pull/325.
#     170     if gc_after_trial:
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\optuna\study\_optimize.py:262, in _run_trial(study, func, catch)
#     255         assert False, "Should not reach."
#     257 if (
#     258     updated_state == TrialState.FAIL
#     259     and func_err is not None
#     260     and not isinstance(func_err, catch)
#     261 ):
# --> 262     raise func_err
#     263 return trial._trial_id
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\optuna\study\_optimize.py:205, in _run_trial(study, func, catch)
#     203 with get_heartbeat_thread(trial._trial_id, study._storage):
#     204     try:
# --> 205         value_or_values = func(trial)
#     206     except exceptions.TrialPruned as e:
#     207         # TODO(mamu): Handle multi-objective cases.
#     208         state = TrialState.PRUNED
#
# File ~\Desktop\TFM\HRL_MAML_StockTrading\src\hyperparameter_searching\HRL_optuna_utils.py:114, in hyperparams_opt_HRL.objective(self, trial)
#     101 initial_cycle_episodes = 4
#     103 model = HRLAgent(
#     104     env=train_env,
#     105     stock_dim=self.stock_dimension,
#    (...)    111     initial_cycle_steps=initial_cycle_episodes * self.episode_len,
#     112 )
# --> 114 trained_model = model.train_HRL_model()
#     116 df_account_value, _, _ = trained_model.predictHRL(env=test_env)
#     118 return df_account_value.account_value.iloc[-1]
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\src\agent\HRL_model.py:278, in HRLAgent.train_HRL_model(self)
#     276 self.ph1_manager_training()
#     277 self.ph2_worker_training()
# --> 278 self.alternate_training()
#     279 return self
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\src\agent\HRL_model.py:262, in HRLAgent.alternate_training(self)
#     254     self.trainHRL(
#     255         total_timesteps=steps_cycle,
#     256         reset_timesteps=False,
#    (...)    259         only_alignment_rew=False,
#     260     )
#     261     self.manager.policy.eval()
# --> 262     self.trainHRL(
#     263         total_timesteps=steps_cycle,
#     264         reset_timesteps=False,
#     265         freeze_M=True,
#     266         freeze_W=False,
#     267         only_alignment_rew=True,
#     268     )
#     270     print(f"[Cycle {cycle+1}/{self.n_alt_cycles}] done")
#     272 return self
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\src\agent\HRL_model.py:159, in HRLAgent.trainHRL(self, total_timesteps, reset_timesteps, freeze_M, freeze_W, only_alignment_rew, reset_ep)
#     153     if not freeze_W:
#     154         if (
#     155             self.worker.num_timesteps > self.worker.learning_starts
#     156             and self.worker.replay_buffer.size()
#     157             > self.worker.batch_size
#     158         ):
# --> 159             self.worker.train(
#     160                 gradient_steps=1,
#     161                 batch_size=self.worker.batch_size,
#     162             )
#     164 obs_W_raw = np.array(obs_W_raw, dtype=np.float32)
#     165 obs_W_raw[-self.stock_dim :] = actions_M
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\stable_baselines3\td3\td3.py:179, in TD3.train(self, gradient_steps, batch_size)
#     176     target_q_values = replay_data.rewards + (1 - replay_data.dones) * self.gamma * next_q_values
#     178 # Get current Q-values estimates for each critic network
# --> 179 current_q_values = self.critic(replay_data.observations, replay_data.actions)
#     181 # Compute critic loss
#     182 critic_loss = sum(F.mse_loss(current_q, target_q_values) for current_q in current_q_values)
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\stable_baselines3\common\policies.py:977, in ContinuousCritic.forward(self, obs, actions)
#     975     features = self.extract_features(obs, self.features_extractor)
#     976 qvalue_input = th.cat([features, actions], dim=1)
# --> 977 return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\stable_baselines3\common\policies.py:977, in <genexpr>(.0)
#     975     features = self.extract_features(obs, self.features_extractor)
#     976 qvalue_input = th.cat([features, actions], dim=1)
# --> 977 return tuple(q_net(qvalue_input) for q_net in self.q_networks)
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\andoni.iribarren\Desktop\TFM\HRL_MAML_StockTrading\hrlenv\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training

# %%
# TRAINING with BEST HPs
from env_stocktrading.trading_env_HRL import StockTradingEnvHRL
from agent.HRL_model import HRLAgent

episode_len = df_train.dayorder.nunique()
state_space_manager = stock_dimension + len(INDICATORS) * stock_dimension
state_space_worker = 1 + 3 * stock_dimension

buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

hrl_train_env = StockTradingEnvHRL(
    df=df_train,
    stock_dim=stock_dimension,
    hmax=100,
    initial_amount=1000000,
    num_stock_shares=num_stock_shares,
    buy_cost_pct=buy_cost_list,
    sell_cost_pct=sell_cost_list,
    state_space_M=state_space_manager,
    state_space_W=state_space_worker,
    action_space=stock_dimension,
    tech_indicator_list=INDICATORS,
    make_plots=False,
    print_verbosity=1,
)

best_params = settings.best_hiperparams_HRL_worker_update

best_params_manager = {
    "lr_actor": best_params["lr_actor_M"],
    "lr_critic": best_params["lr_critic_M"],
    "gamma": best_params["gamma_M"],
    "K_epochs": 80,
    "eps_clip": 0.2,
    "update_timestep": best_params["update_timestep"],
}

best_params_worker = {
    "learning_rate": best_params["lr_W"],
    "tau": 0.005,
    "buffer_size": best_params["buffer_size"],
    "batch_size": best_params["batch_size"],
    "gamma": best_params["gamma_W"],
    "verbose": 1,
}

initial_manager_episodes = 40
initial_worker_episodes = 40
initial_cycle_episodes = 10
n_cycles = 16

model = HRLAgent(
    env=hrl_train_env,
    stock_dim=stock_dimension,
    manager_kwargs=best_params_manager,
    worker_kwargs=best_params_worker,
    initial_manager_timesteps=initial_manager_episodes * episode_len,  # initial_manager_episodes
    initial_worker_timesteps=initial_worker_episodes * episode_len,   # initial_worker_episodes
    n_alt_cycles=n_cycles,                                              # n_cycles
    initial_cycle_steps=initial_cycle_episodes * episode_len,        # initial_cycle_episodes
)

trained_model = model.train_HRL_model()
# Out:
# ============================================================================================
# Device set to : cpu
# ============================================================================================
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Starting Phase 1: Only train Manager
# day: 1007, episode: 1
# begin_total_asset: 1000000.00
# end_total_asset: 1706199.79
# total_reward: 706199.79
# total_cost: 29184.65
# total_trades: 6543
# Sharpe: 1.044
# =================================
# day: 1007, episode: 2
# begin_total_asset: 1000000.00
# end_total_asset: 1892322.04
# total_reward: 892322.04
# total_cost: 29371.37
# total_trades: 6546
# Sharpe: 1.009
# =================================
# day: 1007, episode: 3
# begin_total_asset: 1000000.00
# end_total_asset: 1905436.68
# total_reward: 905436.68
# total_cost: 29249.67
# total_trades: 6517
# Sharpe: 1.064
# =================================
# day: 1007, episode: 4
# begin_total_asset: 1000000.00
# end_total_asset: 2072163.03
# total_reward: 1072163.03
# total_cost: 29574.59
# total_trades: 6422
# Sharpe: 1.342
# =================================
# day: 1007, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2013588.32
# total_reward: 1013588.32
# total_cost: 30185.53
# total_trades: 6538
# Sharpe: 1.215
# =================================
# day: 1007, episode: 6
# begin_total_asset: 1000000.00
# end_total_asset: 2166771.09
# total_reward: 1166771.09
# total_cost: 28608.20
# total_trades: 6423
# Sharpe: 1.234
# =================================
# day: 1007, episode: 7
# begin_total_asset: 1000000.00
# end_total_asset: 2115865.36
# total_reward: 1115865.36
# total_cost: 29213.79
# total_trades: 6592
# Sharpe: 1.045
# =================================
# day: 1007, episode: 8
# begin_total_asset: 1000000.00
# end_total_asset: 1842068.38
# total_reward: 842068.38
# total_cost: 27042.18
# total_trades: 6374
# Sharpe: 0.755
# =================================
# day: 1007, episode: 9
# begin_total_asset: 1000000.00
# end_total_asset: 1938847.68
# total_reward: 938847.68
# total_cost: 28453.42
# total_trades: 6547
# Sharpe: 1.014
# =================================
# day: 1007, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 2035106.68
# total_reward: 1035106.68
# total_cost: 29025.11
# total_trades: 6511
# Sharpe: 1.084
# =================================
# day: 1007, episode: 11
# begin_total_asset: 1000000.00
# end_total_asset: 1998555.35
# total_reward: 998555.35
# total_cost: 28001.66
# total_trades: 6475
# Sharpe: 1.130
# =================================
# day: 1007, episode: 12
# begin_total_asset: 1000000.00
# end_total_asset: 2103703.60
# total_reward: 1103703.60
# total_cost: 27423.68
# total_trades: 6432
# Sharpe: 0.928
# =================================
# day: 1007, episode: 13
# begin_total_asset: 1000000.00
# end_total_asset: 1885230.55
# total_reward: 885230.55
# total_cost: 26717.68
# total_trades: 6408
# Sharpe: 0.985
# =================================
# day: 1007, episode: 14
# begin_total_asset: 1000000.00
# end_total_asset: 2078533.49
# total_reward: 1078533.49
# total_cost: 28127.91
# total_trades: 6440
# Sharpe: 0.972
# =================================
# day: 1007, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 2090811.18
# total_reward: 1090811.18
# total_cost: 29286.64
# total_trades: 6656
# Sharpe: 1.068
# =================================
# day: 1007, episode: 16
# begin_total_asset: 1000000.00
# end_total_asset: 2072608.45
# total_reward: 1072608.45
# total_cost: 26823.64
# total_trades: 6414
# Sharpe: 0.978
# =================================
# day: 1007, episode: 17
# begin_total_asset: 1000000.00
# end_total_asset: 1943016.80
# total_reward: 943016.80
# total_cost: 25921.78
# total_trades: 6335
# Sharpe: 1.035
# =================================
# day: 1007, episode: 18
# begin_total_asset: 1000000.00
# end_total_asset: 1979106.04
# total_reward: 979106.04
# total_cost: 24349.76
# total_trades: 6303
# Sharpe: 0.913
# =================================
# day: 1007, episode: 19
# begin_total_asset: 1000000.00
# end_total_asset: 2026340.24
# total_reward: 1026340.24
# total_cost: 25617.54
# total_trades: 6371
# Sharpe: 1.044
# =================================
# day: 1007, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 2224095.81
# total_reward: 1224095.81
# total_cost: 26186.30
# total_trades: 6340
# Sharpe: 1.067
# =================================
# day: 1007, episode: 21
# begin_total_asset: 1000000.00
# end_total_asset: 2161571.47
# total_reward: 1161571.47
# total_cost: 25336.99
# total_trades: 6323
# Sharpe: 1.016
# =================================
# day: 1007, episode: 22
# begin_total_asset: 1000000.00
# end_total_asset: 2351470.50
# total_reward: 1351470.50
# total_cost: 25821.64
# total_trades: 6215
# Sharpe: 1.126
# =================================
# day: 1007, episode: 23
# begin_total_asset: 1000000.00
# end_total_asset: 2036213.01
# total_reward: 1036213.01
# total_cost: 23244.57
# total_trades: 6191
# Sharpe: 1.022
# =================================
# day: 1007, episode: 24
# begin_total_asset: 1000000.00
# end_total_asset: 2256918.50
# total_reward: 1256918.50
# total_cost: 24790.14
# total_trades: 6249
# Sharpe: 1.053
# =================================
# day: 1007, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 2089152.50
# total_reward: 1089152.50
# total_cost: 24307.54
# total_trades: 6261
# Sharpe: 1.015
# =================================
# day: 1007, episode: 26
# begin_total_asset: 1000000.00
# end_total_asset: 1969982.23
# total_reward: 969982.23
# total_cost: 25153.35
# total_trades: 6331
# Sharpe: 0.956
# =================================
# day: 1007, episode: 27
# begin_total_asset: 1000000.00
# end_total_asset: 2250045.16
# total_reward: 1250045.16
# total_cost: 24837.12
# total_trades: 6239
# Sharpe: 1.094
# =================================
# day: 1007, episode: 28
# begin_total_asset: 1000000.00
# end_total_asset: 1957078.90
# total_reward: 957078.90
# total_cost: 24309.24
# total_trades: 6210
# Sharpe: 0.928
# =================================
# day: 1007, episode: 29
# begin_total_asset: 1000000.00
# end_total_asset: 1938678.73
# total_reward: 938678.73
# total_cost: 25540.49
# total_trades: 6205
# Sharpe: 0.966
# =================================
# day: 1007, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 2092470.93
# total_reward: 1092470.93
# total_cost: 24744.70
# total_trades: 6285
# Sharpe: 0.986
# =================================
# day: 1007, episode: 31
# begin_total_asset: 1000000.00
# end_total_asset: 2213640.67
# total_reward: 1213640.67
# total_cost: 23220.86
# total_trades: 6215
# Sharpe: 1.055
# =================================
# day: 1007, episode: 32
# begin_total_asset: 1000000.00
# end_total_asset: 2153065.48
# total_reward: 1153065.48
# total_cost: 23745.03
# total_trades: 6292
# Sharpe: 1.060
# =================================
# day: 1007, episode: 33
# begin_total_asset: 1000000.00
# end_total_asset: 2188937.88
# total_reward: 1188937.88
# total_cost: 24038.96
# total_trades: 6263
# Sharpe: 1.096
# =================================
# day: 1007, episode: 34
# begin_total_asset: 1000000.00
# end_total_asset: 2090660.07
# total_reward: 1090660.07
# total_cost: 23733.43
# total_trades: 6238
# Sharpe: 1.096
# =================================
# day: 1007, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 2028375.93
# total_reward: 1028375.93
# total_cost: 23529.66
# total_trades: 6141
# Sharpe: 1.030
# =================================
# day: 1007, episode: 36
# begin_total_asset: 1000000.00
# end_total_asset: 1978704.58
# total_reward: 978704.58
# total_cost: 21938.71
# total_trades: 6045
# Sharpe: 1.035
# =================================
# day: 1007, episode: 37
# begin_total_asset: 1000000.00
# end_total_asset: 2109107.92
# total_reward: 1109107.92
# total_cost: 24220.22
# total_trades: 6201
# Sharpe: 1.098
# =================================
# day: 1007, episode: 38
# begin_total_asset: 1000000.00
# end_total_asset: 2259973.76
# total_reward: 1259973.76
# total_cost: 22402.44
# total_trades: 5990
# Sharpe: 1.166
# =================================
# day: 1007, episode: 39
# begin_total_asset: 1000000.00
# end_total_asset: 1955517.92
# total_reward: 955517.92
# total_cost: 23653.06
# total_trades: 6157
# Sharpe: 0.939
# =================================
# day: 1007, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1955847.65
# total_reward: 955847.65
# total_cost: 22301.26
# total_trades: 6176
# Sharpe: 0.963
# =================================
# Starting Phase 2: Only train Worker
# day: 1007, episode: 41
# begin_total_asset: 1000000.00
# end_total_asset: 2250714.73
# total_reward: 1250714.73
# total_cost: 14286.24
# total_trades: 5465
# Sharpe: 1.071
# =================================
# day: 1007, episode: 42
# begin_total_asset: 1000000.00
# end_total_asset: 2250714.73
# total_reward: 1250714.73
# total_cost: 14286.24
# total_trades: 5465
# Sharpe: 1.071
# =================================
# day: 1007, episode: 43
# begin_total_asset: 1000000.00
# end_total_asset: 2250714.73
# total_reward: 1250714.73
# total_cost: 14286.24
# total_trades: 5465
# Sharpe: 1.071
# =================================
# day: 1007, episode: 44
# begin_total_asset: 1000000.00
# end_total_asset: 2250714.73
# total_reward: 1250714.73
# total_cost: 14286.24
# total_trades: 5465
# Sharpe: 1.071
# =================================
# day: 1007, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 2250714.73
# total_reward: 1250714.73
# total_cost: 14286.24
# total_trades: 5465
# Sharpe: 1.071
# =================================
# day: 1007, episode: 46
# begin_total_asset: 1000000.00
# end_total_asset: 2250714.73
# total_reward: 1250714.73
# total_cost: 14286.24
# total_trades: 5465
# Sharpe: 1.071
# =================================
# day: 1007, episode: 47
# begin_total_asset: 1000000.00
# end_total_asset: 2250714.73
# total_reward: 1250714.73
# total_cost: 14286.24
# total_trades: 5465
# Sharpe: 1.071
# =================================
# day: 1007, episode: 48
# begin_total_asset: 1000000.00
# end_total_asset: 2250714.73
# total_reward: 1250714.73
# total_cost: 14286.24
# total_trades: 5465
# Sharpe: 1.071
# =================================
# day: 1007, episode: 49
# begin_total_asset: 1000000.00
# end_total_asset: 2250714.73
# total_reward: 1250714.73
# total_cost: 14286.24
# total_trades: 5465
# Sharpe: 1.071
# =================================
# day: 1007, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 2258983.70
# total_reward: 1258983.70
# total_cost: 14353.39
# total_trades: 5262
# Sharpe: 1.074
# =================================
# day: 1007, episode: 51
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 52
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 53
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 54
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 56
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 57
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 58
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 59
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 61
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 62
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 63
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 64
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 66
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 67
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 68
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 69
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 71
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 72
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 73
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 74
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 76
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 77
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 78
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 79
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# day: 1007, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 2303914.18
# total_reward: 1303914.18
# total_cost: 18271.03
# total_trades: 3239
# Sharpe: 1.177
# =================================
# Starting Phase 3: Alternate training
# day: 1007, episode: 81
# begin_total_asset: 1000000.00
# end_total_asset: 2056276.68
# total_reward: 1056276.68
# total_cost: 28474.81
# total_trades: 3590
# Sharpe: 1.069
# =================================
# day: 1007, episode: 82
# begin_total_asset: 1000000.00
# end_total_asset: 2065916.63
# total_reward: 1065916.63
# total_cost: 29517.51
# total_trades: 3634
# Sharpe: 1.055
# =================================
# day: 1007, episode: 83
# begin_total_asset: 1000000.00
# end_total_asset: 2248832.73
# total_reward: 1248832.73
# total_cost: 29638.03
# total_trades: 3630
# Sharpe: 1.141
# =================================
# day: 1007, episode: 84
# begin_total_asset: 1000000.00
# end_total_asset: 2081144.83
# total_reward: 1081144.83
# total_cost: 28530.16
# total_trades: 3592
# Sharpe: 1.031
# =================================
# day: 1007, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 1897062.35
# total_reward: 897062.35
# total_cost: 30550.17
# total_trades: 3713
# Sharpe: 0.915
# =================================
# day: 1007, episode: 86
# begin_total_asset: 1000000.00
# end_total_asset: 1855177.36
# total_reward: 855177.36
# total_cost: 29178.50
# total_trades: 3682
# Sharpe: 0.895
# =================================
# day: 1007, episode: 87
# begin_total_asset: 1000000.00
# end_total_asset: 1679500.84
# total_reward: 679500.84
# total_cost: 27660.93
# total_trades: 3566
# Sharpe: 0.780
# =================================
# day: 1007, episode: 88
# begin_total_asset: 1000000.00
# end_total_asset: 1936660.68
# total_reward: 936660.68
# total_cost: 28541.59
# total_trades: 3631
# Sharpe: 1.004
# =================================
# day: 1007, episode: 89
# begin_total_asset: 1000000.00
# end_total_asset: 1902477.82
# total_reward: 902477.82
# total_cost: 28559.55
# total_trades: 3644
# Sharpe: 0.964
# =================================
# day: 1007, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 1954224.28
# total_reward: 954224.28
# total_cost: 28584.00
# total_trades: 3615
# Sharpe: 1.053
# =================================
# day: 1007, episode: 91
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# day: 1007, episode: 92
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# day: 1007, episode: 93
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# day: 1007, episode: 94
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# day: 1007, episode: 95
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# day: 1007, episode: 96
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# day: 1007, episode: 97
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# day: 1007, episode: 98
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# day: 1007, episode: 99
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# day: 1007, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 2098566.03
# total_reward: 1098566.03
# total_cost: 19538.57
# total_trades: 3082
# Sharpe: 1.079
# =================================
# [Cycle 1/16] done
# day: 1007, episode: 101
# begin_total_asset: 1000000.00
# end_total_asset: 1971535.08
# total_reward: 971535.08
# total_cost: 28867.84
# total_trades: 3596
# Sharpe: 1.040
# =================================
# day: 1007, episode: 102
# begin_total_asset: 1000000.00
# end_total_asset: 1819054.45
# total_reward: 819054.45
# total_cost: 29925.13
# total_trades: 3566
# Sharpe: 0.942
# =================================
# day: 1007, episode: 103
# begin_total_asset: 1000000.00
# end_total_asset: 1944819.24
# total_reward: 944819.24
# total_cost: 30198.43
# total_trades: 3588
# Sharpe: 0.987
# =================================
# day: 1007, episode: 104
# begin_total_asset: 1000000.00
# end_total_asset: 2004878.59
# total_reward: 1004878.59
# total_cost: 28358.07
# total_trades: 3472
# Sharpe: 1.035
# =================================
# day: 1007, episode: 105
# begin_total_asset: 1000000.00
# end_total_asset: 2058123.84
# total_reward: 1058123.84
# total_cost: 28682.79
# total_trades: 3536
# Sharpe: 1.065
# =================================
# day: 1007, episode: 106
# begin_total_asset: 1000000.00
# end_total_asset: 2133296.49
# total_reward: 1133296.49
# total_cost: 29050.00
# total_trades: 3467
# Sharpe: 1.036
# =================================
# day: 1007, episode: 107
# begin_total_asset: 1000000.00
# end_total_asset: 2107626.12
# total_reward: 1107626.12
# total_cost: 29177.97
# total_trades: 3473
# Sharpe: 1.108
# =================================
# day: 1007, episode: 108
# begin_total_asset: 1000000.00
# end_total_asset: 2236806.09
# total_reward: 1236806.09
# total_cost: 28594.87
# total_trades: 3453
# Sharpe: 1.085
# =================================
# day: 1007, episode: 109
# begin_total_asset: 1000000.00
# end_total_asset: 1892083.76
# total_reward: 892083.76
# total_cost: 26639.54
# total_trades: 3337
# Sharpe: 0.930
# =================================
# day: 1007, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 1958375.40
# total_reward: 958375.40
# total_cost: 27529.67
# total_trades: 3468
# Sharpe: 1.003
# =================================
# day: 1007, episode: 111
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# day: 1007, episode: 112
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# day: 1007, episode: 113
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# day: 1007, episode: 114
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# day: 1007, episode: 115
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# day: 1007, episode: 116
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# day: 1007, episode: 117
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# day: 1007, episode: 118
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# day: 1007, episode: 119
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# day: 1007, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 2169391.82
# total_reward: 1169391.82
# total_cost: 17046.30
# total_trades: 2932
# Sharpe: 1.097
# =================================
# [Cycle 2/16] done
# day: 1007, episode: 121
# begin_total_asset: 1000000.00
# end_total_asset: 1975845.55
# total_reward: 975845.55
# total_cost: 26260.18
# total_trades: 3401
# Sharpe: 0.974
# =================================
# day: 1007, episode: 122
# begin_total_asset: 1000000.00
# end_total_asset: 1996625.42
# total_reward: 996625.42
# total_cost: 27979.83
# total_trades: 3491
# Sharpe: 1.040
# =================================
# day: 1007, episode: 123
# begin_total_asset: 1000000.00
# end_total_asset: 1875628.81
# total_reward: 875628.81
# total_cost: 26601.52
# total_trades: 3423
# Sharpe: 0.929
# =================================
# day: 1007, episode: 124
# begin_total_asset: 1000000.00
# end_total_asset: 1921053.07
# total_reward: 921053.07
# total_cost: 29489.90
# total_trades: 3507
# Sharpe: 0.990
# =================================
# day: 1007, episode: 125
# begin_total_asset: 1000000.00
# end_total_asset: 2025809.71
# total_reward: 1025809.71
# total_cost: 28387.72
# total_trades: 3557
# Sharpe: 1.047
# =================================
# day: 1007, episode: 126
# begin_total_asset: 1000000.00
# end_total_asset: 2048727.83
# total_reward: 1048727.83
# total_cost: 25877.29
# total_trades: 3402
# Sharpe: 1.051
# =================================
# day: 1007, episode: 127
# begin_total_asset: 1000000.00
# end_total_asset: 1895169.81
# total_reward: 895169.81
# total_cost: 29617.53
# total_trades: 3563
# Sharpe: 0.966
# =================================
# day: 1007, episode: 128
# begin_total_asset: 1000000.00
# end_total_asset: 2144341.90
# total_reward: 1144341.90
# total_cost: 28096.92
# total_trades: 3513
# Sharpe: 1.192
# =================================
# day: 1007, episode: 129
# begin_total_asset: 1000000.00
# end_total_asset: 2094115.08
# total_reward: 1094115.08
# total_cost: 26806.46
# total_trades: 3470
# Sharpe: 1.081
# =================================
# day: 1007, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 2043624.12
# total_reward: 1043624.12
# total_cost: 26768.44
# total_trades: 3444
# Sharpe: 1.061
# =================================
# day: 1007, episode: 131
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# day: 1007, episode: 132
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# day: 1007, episode: 133
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# day: 1007, episode: 134
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# day: 1007, episode: 135
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# day: 1007, episode: 136
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# day: 1007, episode: 137
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# day: 1007, episode: 138
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# day: 1007, episode: 139
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# day: 1007, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 2343287.71
# total_reward: 1343287.71
# total_cost: 19962.98
# total_trades: 3105
# Sharpe: 1.276
# =================================
# [Cycle 3/16] done
# day: 1007, episode: 141
# begin_total_asset: 1000000.00
# end_total_asset: 2179344.58
# total_reward: 1179344.58
# total_cost: 27007.47
# total_trades: 3386
# Sharpe: 1.165
# =================================
# day: 1007, episode: 142
# begin_total_asset: 1000000.00
# end_total_asset: 2130710.04
# total_reward: 1130710.04
# total_cost: 26332.45
# total_trades: 3443
# Sharpe: 1.160
# =================================
# day: 1007, episode: 143
# begin_total_asset: 1000000.00
# end_total_asset: 2082656.58
# total_reward: 1082656.58
# total_cost: 23156.29
# total_trades: 3406
# Sharpe: 1.059
# =================================
# day: 1007, episode: 144
# begin_total_asset: 1000000.00
# end_total_asset: 2266349.07
# total_reward: 1266349.07
# total_cost: 26717.96
# total_trades: 3560
# Sharpe: 1.183
# =================================
# day: 1007, episode: 145
# begin_total_asset: 1000000.00
# end_total_asset: 2102510.23
# total_reward: 1102510.23
# total_cost: 27453.88
# total_trades: 3516
# Sharpe: 1.086
# =================================
# day: 1007, episode: 146
# begin_total_asset: 1000000.00
# end_total_asset: 2218902.12
# total_reward: 1218902.12
# total_cost: 26405.21
# total_trades: 3443
# Sharpe: 1.145
# =================================
# day: 1007, episode: 147
# begin_total_asset: 1000000.00
# end_total_asset: 2143102.98
# total_reward: 1143102.98
# total_cost: 26285.08
# total_trades: 3585
# Sharpe: 1.093
# =================================
# day: 1007, episode: 148
# begin_total_asset: 1000000.00
# end_total_asset: 2095544.76
# total_reward: 1095544.76
# total_cost: 28176.58
# total_trades: 3547
# Sharpe: 1.093
# =================================
# day: 1007, episode: 149
# begin_total_asset: 1000000.00
# end_total_asset: 2153407.08
# total_reward: 1153407.08
# total_cost: 27251.38
# total_trades: 3447
# Sharpe: 1.109
# =================================
# day: 1007, episode: 150
# begin_total_asset: 1000000.00
# end_total_asset: 2071647.34
# total_reward: 1071647.34
# total_cost: 26504.82
# total_trades: 3461
# Sharpe: 1.096
# =================================
# day: 1007, episode: 151
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# day: 1007, episode: 152
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# day: 1007, episode: 153
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# day: 1007, episode: 154
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# day: 1007, episode: 155
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# day: 1007, episode: 156
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# day: 1007, episode: 157
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# day: 1007, episode: 158
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# day: 1007, episode: 159
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# day: 1007, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 2116796.07
# total_reward: 1116796.07
# total_cost: 16058.59
# total_trades: 2765
# Sharpe: 1.067
# =================================
# [Cycle 4/16] done
# day: 1007, episode: 161
# begin_total_asset: 1000000.00
# end_total_asset: 2074462.74
# total_reward: 1074462.74
# total_cost: 27477.78
# total_trades: 3416
# Sharpe: 1.079
# =================================
# day: 1007, episode: 162
# begin_total_asset: 1000000.00
# end_total_asset: 2024520.46
# total_reward: 1024520.46
# total_cost: 26657.12
# total_trades: 3407
# Sharpe: 1.041
# =================================
# day: 1007, episode: 163
# begin_total_asset: 1000000.00
# end_total_asset: 2359996.81
# total_reward: 1359996.81
# total_cost: 28243.87
# total_trades: 3497
# Sharpe: 1.176
# =================================
# day: 1007, episode: 164
# begin_total_asset: 1000000.00
# end_total_asset: 2179608.12
# total_reward: 1179608.12
# total_cost: 28426.88
# total_trades: 3550
# Sharpe: 1.166
# =================================
# day: 1007, episode: 165
# begin_total_asset: 1000000.00
# end_total_asset: 2420609.44
# total_reward: 1420609.44
# total_cost: 27205.45
# total_trades: 3462
# Sharpe: 1.189
# =================================
# day: 1007, episode: 166
# begin_total_asset: 1000000.00
# end_total_asset: 2370379.50
# total_reward: 1370379.50
# total_cost: 28038.13
# total_trades: 3537
# Sharpe: 1.193
# =================================
# day: 1007, episode: 167
# begin_total_asset: 1000000.00
# end_total_asset: 2243904.72
# total_reward: 1243904.72
# total_cost: 28261.47
# total_trades: 3595
# Sharpe: 1.057
# =================================
# day: 1007, episode: 168
# begin_total_asset: 1000000.00
# end_total_asset: 2455675.75
# total_reward: 1455675.75
# total_cost: 29251.55
# total_trades: 3604
# Sharpe: 1.248
# =================================
# day: 1007, episode: 169
# begin_total_asset: 1000000.00
# end_total_asset: 2254536.12
# total_reward: 1254536.12
# total_cost: 27180.19
# total_trades: 3555
# Sharpe: 1.037
# =================================
# day: 1007, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 1972037.03
# total_reward: 972037.03
# total_cost: 28297.68
# total_trades: 3635
# Sharpe: 0.980
# =================================
# day: 1007, episode: 171
# begin_total_asset: 1000000.00
# end_total_asset: 2257723.42
# total_reward: 1257723.42
# total_cost: 15793.89
# total_trades: 3379
# Sharpe: 0.985
# =================================
# day: 1007, episode: 172
# begin_total_asset: 1000000.00
# end_total_asset: 2257889.88
# total_reward: 1257889.88
# total_cost: 15795.61
# total_trades: 3381
# Sharpe: 0.985
# =================================
# day: 1007, episode: 173
# begin_total_asset: 1000000.00
# end_total_asset: 2257889.88
# total_reward: 1257889.88
# total_cost: 15795.61
# total_trades: 3381
# Sharpe: 0.985
# =================================
# day: 1007, episode: 174
# begin_total_asset: 1000000.00
# end_total_asset: 2257889.88
# total_reward: 1257889.88
# total_cost: 15795.61
# total_trades: 3381
# Sharpe: 0.985
# =================================
# day: 1007, episode: 175
# begin_total_asset: 1000000.00
# end_total_asset: 2257889.88
# total_reward: 1257889.88
# total_cost: 15795.61
# total_trades: 3381
# Sharpe: 0.985
# =================================
# day: 1007, episode: 176
# begin_total_asset: 1000000.00
# end_total_asset: 2257889.88
# total_reward: 1257889.88
# total_cost: 15795.61
# total_trades: 3381
# Sharpe: 0.985
# =================================
# day: 1007, episode: 177
# begin_total_asset: 1000000.00
# end_total_asset: 2257889.88
# total_reward: 1257889.88
# total_cost: 15795.61
# total_trades: 3381
# Sharpe: 0.985
# =================================
# day: 1007, episode: 178
# begin_total_asset: 1000000.00
# end_total_asset: 2257889.88
# total_reward: 1257889.88
# total_cost: 15795.61
# total_trades: 3381
# Sharpe: 0.985
# =================================
# day: 1007, episode: 179
# begin_total_asset: 1000000.00
# end_total_asset: 2257889.88
# total_reward: 1257889.88
# total_cost: 15795.61
# total_trades: 3381
# Sharpe: 0.985
# =================================
# day: 1007, episode: 180
# begin_total_asset: 1000000.00
# end_total_asset: 2257889.88
# total_reward: 1257889.88
# total_cost: 15795.61
# total_trades: 3381
# Sharpe: 0.985
# =================================
# [Cycle 5/16] done
# day: 1007, episode: 181
# begin_total_asset: 1000000.00
# end_total_asset: 2016278.73
# total_reward: 1016278.73
# total_cost: 25711.74
# total_trades: 4126
# Sharpe: 0.901
# =================================
# day: 1007, episode: 182
# begin_total_asset: 1000000.00
# end_total_asset: 2103728.90
# total_reward: 1103728.90
# total_cost: 26640.06
# total_trades: 4162
# Sharpe: 0.989
# =================================
# day: 1007, episode: 183
# begin_total_asset: 1000000.00
# end_total_asset: 2193525.28
# total_reward: 1193525.28
# total_cost: 25647.08
# total_trades: 4085
# Sharpe: 0.958
# =================================
# day: 1007, episode: 184
# begin_total_asset: 1000000.00
# end_total_asset: 2081786.83
# total_reward: 1081786.83
# total_cost: 28362.69
# total_trades: 4173
# Sharpe: 0.970
# =================================
# day: 1007, episode: 185
# begin_total_asset: 1000000.00
# end_total_asset: 2023263.92
# total_reward: 1023263.92
# total_cost: 27155.16
# total_trades: 4085
# Sharpe: 1.019
# =================================
# day: 1007, episode: 186
# begin_total_asset: 1000000.00
# end_total_asset: 2038276.27
# total_reward: 1038276.27
# total_cost: 27506.47
# total_trades: 4112
# Sharpe: 1.040
# =================================
# day: 1007, episode: 187
# begin_total_asset: 1000000.00
# end_total_asset: 1905768.96
# total_reward: 905768.96
# total_cost: 27596.70
# total_trades: 4099
# Sharpe: 0.870
# =================================
# day: 1007, episode: 188
# begin_total_asset: 1000000.00
# end_total_asset: 1951598.54
# total_reward: 951598.54
# total_cost: 27734.71
# total_trades: 4105
# Sharpe: 1.028
# =================================
# day: 1007, episode: 189
# begin_total_asset: 1000000.00
# end_total_asset: 1987811.13
# total_reward: 987811.13
# total_cost: 26852.91
# total_trades: 4110
# Sharpe: 1.007
# =================================
# day: 1007, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 1917883.07
# total_reward: 917883.07
# total_cost: 26932.94
# total_trades: 4143
# Sharpe: 0.928
# =================================
# day: 1007, episode: 191
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# day: 1007, episode: 192
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# day: 1007, episode: 193
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# day: 1007, episode: 194
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# day: 1007, episode: 195
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# day: 1007, episode: 196
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# day: 1007, episode: 197
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# day: 1007, episode: 198
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# day: 1007, episode: 199
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# day: 1007, episode: 200
# begin_total_asset: 1000000.00
# end_total_asset: 2309472.16
# total_reward: 1309472.16
# total_cost: 19080.85
# total_trades: 3598
# Sharpe: 1.008
# =================================
# [Cycle 6/16] done
# day: 1007, episode: 201
# begin_total_asset: 1000000.00
# end_total_asset: 1965404.47
# total_reward: 965404.47
# total_cost: 25733.70
# total_trades: 4096
# Sharpe: 1.001
# =================================
# day: 1007, episode: 202
# begin_total_asset: 1000000.00
# end_total_asset: 1873118.36
# total_reward: 873118.36
# total_cost: 26001.94
# total_trades: 4220
# Sharpe: 0.993
# =================================
# day: 1007, episode: 203
# begin_total_asset: 1000000.00
# end_total_asset: 1971518.92
# total_reward: 971518.92
# total_cost: 27304.66
# total_trades: 4117
# Sharpe: 1.094
# =================================
# day: 1007, episode: 204
# begin_total_asset: 1000000.00
# end_total_asset: 2016297.73
# total_reward: 1016297.73
# total_cost: 26182.90
# total_trades: 4089
# Sharpe: 1.077
# =================================
# day: 1007, episode: 205
# begin_total_asset: 1000000.00
# end_total_asset: 2026650.83
# total_reward: 1026650.83
# total_cost: 26511.02
# total_trades: 4084
# Sharpe: 1.000
# =================================
# day: 1007, episode: 206
# begin_total_asset: 1000000.00
# end_total_asset: 1994252.47
# total_reward: 994252.47
# total_cost: 27421.84
# total_trades: 4084
# Sharpe: 1.000
# =================================
# day: 1007, episode: 207
# begin_total_asset: 1000000.00
# end_total_asset: 1923620.41
# total_reward: 923620.41
# total_cost: 27027.82
# total_trades: 4088
# Sharpe: 1.000
# =================================
# day: 1007, episode: 208
# begin_total_asset: 1000000.00
# end_total_asset: 1999293.35
# total_reward: 999293.35
# total_cost: 27461.11
# total_trades: 4214
# Sharpe: 1.017
# =================================
# day: 1007, episode: 209
# begin_total_asset: 1000000.00
# end_total_asset: 2195711.83
# total_reward: 1195711.83
# total_cost: 28521.72
# total_trades: 4317
# Sharpe: 1.125
# =================================
# day: 1007, episode: 210
# begin_total_asset: 1000000.00
# end_total_asset: 2111415.15
# total_reward: 1111415.15
# total_cost: 28473.22
# total_trades: 4335
# Sharpe: 1.070
# =================================
# day: 1007, episode: 211
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# day: 1007, episode: 212
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# day: 1007, episode: 213
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# day: 1007, episode: 214
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# day: 1007, episode: 215
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# day: 1007, episode: 216
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# day: 1007, episode: 217
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# day: 1007, episode: 218
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# day: 1007, episode: 219
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# day: 1007, episode: 220
# begin_total_asset: 1000000.00
# end_total_asset: 2530208.73
# total_reward: 1530208.73
# total_cost: 21931.91
# total_trades: 3877
# Sharpe: 1.322
# =================================
# [Cycle 7/16] done
# day: 1007, episode: 221
# begin_total_asset: 1000000.00
# end_total_asset: 2627951.78
# total_reward: 1627951.78
# total_cost: 32783.61
# total_trades: 4427
# Sharpe: 1.410
# =================================
# day: 1007, episode: 222
# begin_total_asset: 1000000.00
# end_total_asset: 2270286.85
# total_reward: 1270286.85
# total_cost: 33756.41
# total_trades: 4461
# Sharpe: 1.300
# =================================
# day: 1007, episode: 223
# begin_total_asset: 1000000.00
# end_total_asset: 2227308.26
# total_reward: 1227308.26
# total_cost: 33862.55
# total_trades: 4452
# Sharpe: 1.202
# =================================
# day: 1007, episode: 224
# begin_total_asset: 1000000.00
# end_total_asset: 2133183.94
# total_reward: 1133183.94
# total_cost: 32666.39
# total_trades: 4397
# Sharpe: 1.383
# =================================
# day: 1007, episode: 225
# begin_total_asset: 1000000.00
# end_total_asset: 1978272.80
# total_reward: 978272.80
# total_cost: 30901.19
# total_trades: 4228
# Sharpe: 1.155
# =================================
# day: 1007, episode: 226
# begin_total_asset: 1000000.00
# end_total_asset: 2096614.72
# total_reward: 1096614.72
# total_cost: 30670.79
# total_trades: 4431
# Sharpe: 1.101
# =================================
# day: 1007, episode: 227
# begin_total_asset: 1000000.00
# end_total_asset: 1927602.99
# total_reward: 927602.99
# total_cost: 29754.32
# total_trades: 4256
# Sharpe: 1.129
# =================================
# day: 1007, episode: 228
# begin_total_asset: 1000000.00
# end_total_asset: 2104601.21
# total_reward: 1104601.21
# total_cost: 29544.43
# total_trades: 4282
# Sharpe: 1.057
# =================================
# day: 1007, episode: 229
# begin_total_asset: 1000000.00
# end_total_asset: 2100615.97
# total_reward: 1100615.97
# total_cost: 29763.27
# total_trades: 4203
# Sharpe: 1.087
# =================================
# day: 1007, episode: 230
# begin_total_asset: 1000000.00
# end_total_asset: 1877350.17
# total_reward: 877350.17
# total_cost: 31804.16
# total_trades: 4247
# Sharpe: 1.067
# =================================
# day: 1007, episode: 231
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# day: 1007, episode: 232
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# day: 1007, episode: 233
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# day: 1007, episode: 234
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# day: 1007, episode: 235
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# day: 1007, episode: 236
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# day: 1007, episode: 237
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# day: 1007, episode: 238
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# day: 1007, episode: 239
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# day: 1007, episode: 240
# begin_total_asset: 1000000.00
# end_total_asset: 2351625.35
# total_reward: 1351625.35
# total_cost: 19518.75
# total_trades: 3684
# Sharpe: 1.219
# =================================
# [Cycle 8/16] done
# day: 1007, episode: 241
# begin_total_asset: 1000000.00
# end_total_asset: 1854524.00
# total_reward: 854524.00
# total_cost: 28709.46
# total_trades: 4153
# Sharpe: 1.002
# =================================
# day: 1007, episode: 242
# begin_total_asset: 1000000.00
# end_total_asset: 1931516.07
# total_reward: 931516.07
# total_cost: 30243.05
# total_trades: 4183
# Sharpe: 1.154
# =================================
# day: 1007, episode: 243
# begin_total_asset: 1000000.00
# end_total_asset: 1671914.79
# total_reward: 671914.79
# total_cost: 30289.91
# total_trades: 4246
# Sharpe: 1.035
# =================================
# day: 1007, episode: 244
# begin_total_asset: 1000000.00
# end_total_asset: 1929099.65
# total_reward: 929099.65
# total_cost: 29698.84
# total_trades: 4328
# Sharpe: 1.081
# =================================
# ...
# total_cost: 24220.58
# total_trades: 3474
# Sharpe: 1.027
# =================================
# day: 1007, episode: 320
# begin_total_asset: 1000000.00
# end_total_asset: 2142208.17
# total_reward: 1142208.17
# total_cost: 24220.58
# total_trades: 3474
# Sharpe: 1.027
# =================================
# [Cycle 12/16] done
# day: 1007, episode: 321
# begin_total_asset: 1000000.00
# end_total_asset: 2033770.91
# total_reward: 1033770.91
# total_cost: 31666.57
# total_trades: 4060
# Sharpe: 1.102
# =================================
# day: 1007, episode: 322
# begin_total_asset: 1000000.00
# end_total_asset: 2104923.13
# total_reward: 1104923.13
# total_cost: 31485.83
# total_trades: 4017
# Sharpe: 0.988
# =================================
# day: 1007, episode: 323
# begin_total_asset: 1000000.00
# end_total_asset: 2275886.03
# total_reward: 1275886.03
# total_cost: 29746.77
# total_trades: 3971
# Sharpe: 1.060
# =================================
# day: 1007, episode: 324
# begin_total_asset: 1000000.00
# end_total_asset: 2248557.30
# total_reward: 1248557.30
# total_cost: 29673.15
# total_trades: 4023
# Sharpe: 0.991
# =================================
# day: 1007, episode: 325
# begin_total_asset: 1000000.00
# end_total_asset: 2217647.00
# total_reward: 1217647.00
# total_cost: 29953.82
# total_trades: 4013
# Sharpe: 0.985
# =================================
# day: 1007, episode: 326
# begin_total_asset: 1000000.00
# end_total_asset: 2233904.86
# total_reward: 1233904.86
# total_cost: 29424.23
# total_trades: 3941
# Sharpe: 1.042
# =================================
# day: 1007, episode: 327
# begin_total_asset: 1000000.00
# end_total_asset: 2299578.55
# total_reward: 1299578.55
# total_cost: 31060.80
# total_trades: 4094
# Sharpe: 1.131
# =================================
# day: 1007, episode: 328
# begin_total_asset: 1000000.00
# end_total_asset: 2220035.27
# total_reward: 1220035.27
# total_cost: 31743.17
# total_trades: 4058
# Sharpe: 1.051
# =================================
# day: 1007, episode: 329
# begin_total_asset: 1000000.00
# end_total_asset: 2218869.79
# total_reward: 1218869.79
# total_cost: 31494.20
# total_trades: 4116
# Sharpe: 1.046
# =================================
# day: 1007, episode: 330
# begin_total_asset: 1000000.00
# end_total_asset: 2339484.12
# total_reward: 1339484.12
# total_cost: 30608.22
# total_trades: 4108
# Sharpe: 1.160
# =================================
# day: 1007, episode: 331
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# day: 1007, episode: 332
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# day: 1007, episode: 333
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# day: 1007, episode: 334
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# day: 1007, episode: 335
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# day: 1007, episode: 336
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# day: 1007, episode: 337
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# day: 1007, episode: 338
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# day: 1007, episode: 339
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# day: 1007, episode: 340
# begin_total_asset: 1000000.00
# end_total_asset: 2468477.55
# total_reward: 1468477.55
# total_cost: 21901.89
# total_trades: 3473
# Sharpe: 1.210
# =================================
# [Cycle 13/16] done
# day: 1007, episode: 341
# begin_total_asset: 1000000.00
# end_total_asset: 2123577.41
# total_reward: 1123577.41
# total_cost: 31159.72
# total_trades: 4049
# Sharpe: 1.085
# =================================
# day: 1007, episode: 342
# begin_total_asset: 1000000.00
# end_total_asset: 2014823.95
# total_reward: 1014823.95
# total_cost: 30902.70
# total_trades: 4041
# Sharpe: 0.990
# =================================
# day: 1007, episode: 343
# begin_total_asset: 1000000.00
# end_total_asset: 2007539.37
# total_reward: 1007539.37
# total_cost: 32720.52
# total_trades: 4093
# Sharpe: 1.054
# =================================
# day: 1007, episode: 344
# begin_total_asset: 1000000.00
# end_total_asset: 2146865.21
# total_reward: 1146865.21
# total_cost: 30477.37
# total_trades: 4056
# Sharpe: 1.113
# =================================
# day: 1007, episode: 345
# begin_total_asset: 1000000.00
# end_total_asset: 2374291.16
# total_reward: 1374291.16
# total_cost: 30641.56
# total_trades: 4117
# Sharpe: 1.174
# =================================
# day: 1007, episode: 346
# begin_total_asset: 1000000.00
# end_total_asset: 2201516.20
# total_reward: 1201516.20
# total_cost: 31012.98
# total_trades: 4117
# Sharpe: 1.092
# =================================
# day: 1007, episode: 347
# begin_total_asset: 1000000.00
# end_total_asset: 2290560.44
# total_reward: 1290560.44
# total_cost: 29818.67
# total_trades: 4080
# Sharpe: 1.083
# =================================
# day: 1007, episode: 348
# begin_total_asset: 1000000.00
# end_total_asset: 2176689.12
# total_reward: 1176689.12
# total_cost: 30598.63
# total_trades: 4086
# Sharpe: 1.140
# =================================
# day: 1007, episode: 349
# begin_total_asset: 1000000.00
# end_total_asset: 2272855.17
# total_reward: 1272855.17
# total_cost: 29466.44
# total_trades: 3995
# Sharpe: 1.169
# =================================
# day: 1007, episode: 350
# begin_total_asset: 1000000.00
# end_total_asset: 2316916.73
# total_reward: 1316916.73
# total_cost: 30302.99
# total_trades: 4123
# Sharpe: 1.132
# =================================
# day: 1007, episode: 351
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# day: 1007, episode: 352
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# day: 1007, episode: 353
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# day: 1007, episode: 354
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# day: 1007, episode: 355
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# day: 1007, episode: 356
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# day: 1007, episode: 357
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# day: 1007, episode: 358
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# day: 1007, episode: 359
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# day: 1007, episode: 360
# begin_total_asset: 1000000.00
# end_total_asset: 2899781.03
# total_reward: 1899781.03
# total_cost: 17571.65
# total_trades: 3323
# Sharpe: 1.294
# =================================
# [Cycle 14/16] done
# day: 1007, episode: 361
# begin_total_asset: 1000000.00
# end_total_asset: 2191510.97
# total_reward: 1191510.97
# total_cost: 28489.80
# total_trades: 4104
# Sharpe: 1.127
# =================================
# day: 1007, episode: 362
# begin_total_asset: 1000000.00
# end_total_asset: 2377151.05
# total_reward: 1377151.05
# total_cost: 29257.49
# total_trades: 4077
# Sharpe: 1.121
# =================================
# day: 1007, episode: 363
# begin_total_asset: 1000000.00
# end_total_asset: 2320442.28
# total_reward: 1320442.28
# total_cost: 31710.69
# total_trades: 4254
# Sharpe: 1.150
# =================================
# day: 1007, episode: 364
# begin_total_asset: 1000000.00
# end_total_asset: 2399520.14
# total_reward: 1399520.14
# total_cost: 31441.09
# total_trades: 4230
# Sharpe: 1.193
# =================================
# day: 1007, episode: 365
# begin_total_asset: 1000000.00
# end_total_asset: 2411988.90
# total_reward: 1411988.90
# total_cost: 31235.85
# total_trades: 4272
# Sharpe: 1.273
# =================================
# day: 1007, episode: 366
# begin_total_asset: 1000000.00
# end_total_asset: 2310776.31
# total_reward: 1310776.31
# total_cost: 28800.10
# total_trades: 4174
# Sharpe: 1.229
# =================================
# day: 1007, episode: 367
# begin_total_asset: 1000000.00
# end_total_asset: 2466300.98
# total_reward: 1466300.98
# total_cost: 30772.19
# total_trades: 4182
# Sharpe: 1.133
# =================================
# day: 1007, episode: 368
# begin_total_asset: 1000000.00
# end_total_asset: 2532610.50
# total_reward: 1532610.50
# total_cost: 29769.00
# total_trades: 4105
# Sharpe: 1.223
# =================================
# day: 1007, episode: 369
# begin_total_asset: 1000000.00
# end_total_asset: 2360979.85
# total_reward: 1360979.85
# total_cost: 29239.72
# total_trades: 4022
# Sharpe: 1.128
# =================================
# day: 1007, episode: 370
# begin_total_asset: 1000000.00
# end_total_asset: 2392136.91
# total_reward: 1392136.91
# total_cost: 28663.95
# total_trades: 4089
# Sharpe: 1.124
# =================================
# day: 1007, episode: 371
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# day: 1007, episode: 372
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# day: 1007, episode: 373
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# day: 1007, episode: 374
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# day: 1007, episode: 375
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# day: 1007, episode: 376
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# day: 1007, episode: 377
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# day: 1007, episode: 378
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# day: 1007, episode: 379
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# day: 1007, episode: 380
# begin_total_asset: 1000000.00
# end_total_asset: 2636026.67
# total_reward: 1636026.67
# total_cost: 20029.39
# total_trades: 3413
# Sharpe: 1.192
# =================================
# [Cycle 15/16] done
# day: 1007, episode: 381
# begin_total_asset: 1000000.00
# end_total_asset: 2489453.51
# total_reward: 1489453.51
# total_cost: 29748.65
# total_trades: 4112
# Sharpe: 1.090
# =================================
# day: 1007, episode: 382
# begin_total_asset: 1000000.00
# end_total_asset: 2372122.92
# total_reward: 1372122.92
# total_cost: 31162.87
# total_trades: 4175
# Sharpe: 1.034
# =================================
# day: 1007, episode: 383
# begin_total_asset: 1000000.00
# end_total_asset: 2260417.15
# total_reward: 1260417.15
# total_cost: 29845.60
# total_trades: 4050
# Sharpe: 0.997
# =================================
# day: 1007, episode: 384
# begin_total_asset: 1000000.00
# end_total_asset: 2484131.87
# total_reward: 1484131.87
# total_cost: 31615.45
# total_trades: 4219
# Sharpe: 1.159
# =================================
# day: 1007, episode: 385
# begin_total_asset: 1000000.00
# end_total_asset: 2487054.48
# total_reward: 1487054.48
# total_cost: 31523.28
# total_trades: 4159
# Sharpe: 1.163
# =================================
# day: 1007, episode: 386
# begin_total_asset: 1000000.00
# end_total_asset: 2224272.45
# total_reward: 1224272.45
# total_cost: 32339.69
# total_trades: 4213
# Sharpe: 1.112
# =================================
# day: 1007, episode: 387
# begin_total_asset: 1000000.00
# end_total_asset: 2345093.08
# total_reward: 1345093.08
# total_cost: 32638.35
# total_trades: 4257
# Sharpe: 1.100
# =================================
# day: 1007, episode: 388
# begin_total_asset: 1000000.00
# end_total_asset: 2248333.19
# total_reward: 1248333.19
# total_cost: 33538.23
# total_trades: 4312
# Sharpe: 1.068
# =================================
# day: 1007, episode: 389
# begin_total_asset: 1000000.00
# end_total_asset: 2323004.36
# total_reward: 1323004.36
# total_cost: 32857.45
# total_trades: 4279
# Sharpe: 1.140
# =================================
# day: 1007, episode: 390
# begin_total_asset: 1000000.00
# end_total_asset: 2333856.01
# total_reward: 1333856.01
# total_cost: 33187.41
# total_trades: 4358
# Sharpe: 1.098
# =================================
# day: 1007, episode: 391
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# day: 1007, episode: 392
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# day: 1007, episode: 393
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# day: 1007, episode: 394
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# day: 1007, episode: 395
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# day: 1007, episode: 396
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# day: 1007, episode: 397
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# day: 1007, episode: 398
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# day: 1007, episode: 399
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# day: 1007, episode: 400
# begin_total_asset: 1000000.00
# end_total_asset: 2231785.44
# total_reward: 1231785.44
# total_cost: 19106.72
# total_trades: 3432
# Sharpe: 0.979
# =================================
# [Cycle 16/16] done

# %%
# VALIDATION
hrl_val_env = StockTradingEnvHRL(
    df=df_val,
    stock_dim=stock_dimension,
    hmax=100,
    initial_amount=1000000,
    num_stock_shares=num_stock_shares,
    buy_cost_pct=buy_cost_list,
    sell_cost_pct=sell_cost_list,
    state_space_M=state_space_manager,
    state_space_W=state_space_worker,
    action_space=stock_dimension,
    tech_indicator_list=INDICATORS,
    make_plots=False,
    print_verbosity=1,
)

df_account_value_hrl, df_actions_hrl, last_state_hrl = trained_model.predictHRL(hrl_val_env)
# Out:
# Retrieving memory from env...
# day: 250, episode: 1
# begin_total_asset: 1000000.00
# end_total_asset: 858816.58
# total_reward: -141183.42
# total_cost: 7188.07
# total_trades: 844
# Sharpe: -0.377
# =================================
# Retrieving memory from env...
# Hit end!

# %%
# AÑO 2023
test23_env = StockTradingEnvHRL(
    df = df_test23,
    stock_dim=stock_dimension,
    hmax=100,
    initial_amount=1000000,
    num_stock_shares=num_stock_shares,
    buy_cost_pct=buy_cost_list,
    sell_cost_pct=sell_cost_list,
    state_space_M=state_space_manager,
    state_space_W=state_space_worker,
    action_space=stock_dimension,
    tech_indicator_list=INDICATORS,
    make_plots=False,
    print_verbosity=1,
)

df_account_test23_HRL, df_actions_test23_HRL, last_state_test23_HRL = trained_model.predictHRL(test23_env)

#df_account_test23_HRL.to_csv("../demo/results/dfs/cuenta_test23_HRL_2.csv")
print(last_state_test23_HRL[31:61])
# Out:
# Retrieving memory from env...
# day: 249, episode: 1
# begin_total_asset: 1000000.00
# end_total_asset: 1177203.52
# total_reward: 177203.52
# total_cost: 7416.71
# total_trades: 906
# Sharpe: 1.322
# =================================
# Retrieving memory from env...
# Hit end!
# [-0.035233365092098165, 0.47168268674679886, 1.1775378387395707, 1.2453903450725883, 0.9979311448508406, 0.3503386763916387, -0.12301718105280655, -0.42070978267871934, -0.32202822863022473, -0.24358370829871812, -0.5386733641215048, 0.21523634948235196, 0.07880746739116744, 0.5316314146098382, 0.6329546684679914, -0.06911936228092377, -0.46105719275840606, 0.04621101204945675, -0.2911170359409034, 1.0833417707929323]

# %%
# AÑO 2024
test24_env = StockTradingEnvHRL(
    df = df_test24,
    stock_dim=stock_dimension,
    hmax=100,
    initial_amount=1000000,
    num_stock_shares=num_stock_shares,
    buy_cost_pct=buy_cost_list,
    sell_cost_pct=sell_cost_list,
    state_space_M=state_space_manager,
    state_space_W=state_space_worker,
    action_space=stock_dimension,
    tech_indicator_list=INDICATORS,
    make_plots=False,
    print_verbosity=1,
)

df_account_test24_HRL, df_actions_test24_HRL, last_state_test24_HRL = trained_model.predictHRL(test24_env)

#df_account_test24_HRL.to_csv("../demo/results/dfs/cuenta_test24_HRL_2.csv")
print(last_state_test24_HRL[31:61])
# Out:
# Retrieving memory from env...
# day: 251, episode: 1
# begin_total_asset: 1000000.00
# end_total_asset: 1470549.39
# total_reward: 470549.39
# total_cost: 9222.27
# total_trades: 836
# Sharpe: 2.488
# =================================
# Retrieving memory from env...
# Hit end!
# [0.6464049836222368, -0.08798847780306396, -0.06714335892060128, -0.774128340317991, -1.3249901113963223, -1.03854239984317, 0.20877387384459337, -1.1417632731649054, -1.5329099098620307, -1.6522045262733287, 0.3438425107959376, -0.44380531607015694, -0.7264353017038232, -1.0644372805997888, -1.099926207683772, -0.9134406780708675, -0.5424966208279056, -1.0041137980113242, -1.4444747682217147, -1.6035355394750603]
